# %% [markdown]
# ## Setup

# %%
import os
import pathlib
from random import choice

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import tensorflow as tf


from tensorflow.keras import layers # type: ignore
from tensorflow.keras import models # type: ignore
from IPython import display
tf.keras.layers

# Set the seed value for experiment reproducibility.
seed = 42
tf.random.set_seed(seed)
np.random.seed(seed)

import wandb

sweep_config = {
    "method": "grid",  
    "metric": {
        "name": "val_accuracy",
        "goal": "maximize"
    },
    "parameters": {
        "learning_rate": {
            "values": [0.001] 
        },
        "dropout_rate": {
            "values": [0.3]
        },
        "epochs": {
            "values": [10]
        },
        "activation_function": {
            "values": ["relu"]
            # "values": ["relu", "sigmoid", "tanh", "leaky_relu"]  # Different activation functions to test
        }
    }
}

sweep_id = wandb.sweep(sweep_config, project="ml_project")
# Out:
# Create sweep with ID: 028l3vuh
# Sweep URL: https://wandb.ai/hermanplay-warsaw-university-of-technology/ml_project/sweeps/028l3vuh

# %% [markdown]
# ### Data Loading and Preprocessing

# %%
#DATASET_PATH = 'train/processed_train'
DATASET_PATH = 'processed_train'
#DATASET_PATH = 'train/train/audio'
data_dir = pathlib.Path(DATASET_PATH)

TEST_PATH = 'test'
test_dir = pathlib.Path(TEST_PATH)

# %%
words = np.array(tf.io.gfile.listdir(str(data_dir)))
#words = np.delete(words, np.where(words == '_background_noise_'))
print('Words:', words)
# Out:
# Words: ['dog' 'down' 'tree' 'right' 'bed' 'up' 'one' 'six' 'yes' 'house' 'four'
#  'stop' 'zero' 'on' 'left' 'five' 'seven' 'three' 'eight' 'sheila' 'cat'
#  'two' 'off' 'marvin' 'nine' 'no' 'go' 'wow' 'bird' 'happy']

# %% [markdown]
# Loading data with audio_dataset_from_directory. The output_sequence_length=16000 pads the short ones to exactly 1 second (and would trim longer ones) so that they can be easily batched.

# %%
train_ds, val_ds = tf.keras.utils.audio_dataset_from_directory(
    directory=data_dir,
    batch_size=64,
    validation_split=0.2,
    seed=0,
    output_sequence_length=16000,
    subset='both')

orig_label_names = np.array(train_ds.class_names)
print()
print("Label names:", orig_label_names)
# Out:
# Found 64721 files belonging to 30 classes.
# Using 51777 files for training.
# Using 12944 files for validation.
# I0000 00:00:1738167257.213923  111985 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5859 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 2070 SUPER, pci bus id: 0000:01:00.0, compute capability: 7.5
# Label names: ['bed' 'bird' 'cat' 'dog' 'down' 'eight' 'five' 'four' 'go' 'happy'
#  'house' 'left' 'marvin' 'nine' 'no' 'off' 'on' 'one' 'right' 'seven'
#  'sheila' 'six' 'stop' 'three' 'tree' 'two' 'up' 'wow' 'yes' 'zero']

# %%
submission_ds = tf.keras.utils.audio_dataset_from_directory(
    directory=test_dir,
    batch_size=64,
    shuffle=False,
    class_names=None,
    output_sequence_length=16000)
# Out:
# Found 148539 files belonging to 1 classes.

# %% [markdown]
# #### Balancing the dataset

# %% [markdown]
# Lets plot bar chart of the current class distribution in train dataset.

# %%
# Calculate and visualize class distribution
def get_class_distribution(dataset):
    """
    Returns the distribution of classes in the dataset.
    """
    class_counts = {}
    for audio, label in dataset.unbatch():
        label_value = label.numpy()
        class_counts[label_value] = class_counts.get(label_value, 0) + 1
    return class_counts

# Visualize class distribution for training data
train_class_counts = get_class_distribution(train_ds)

# Plot the distribution
plt.figure(figsize=(10, 6))
plt.bar(train_class_counts.keys(), train_class_counts.values(), color="skyblue")
plt.xlabel("Class")
plt.ylabel("Number of Samples")
plt.title("Class Distribution in Training Dataset")
plt.xticks(list(train_class_counts.keys()))
plt.grid(axis="y", linestyle="--", alpha=0.7)
plt.show()
# Out:
# 2025-01-29 17:14:32.698256: I tensorflow/core/framework/local_rendezvous.cc:405] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %% [markdown]
# Now, we will create a function to oversample the dataset to ensure all classes have at least  `target_count` samples.

# %%
def oversample_dataset(dataset, target_count):
    # Group samples by class
    class_samples = {}
    for audio_batch, label_batch in dataset:
        for audio, label in zip(audio_batch.numpy(), label_batch.numpy()):
            label_value = int(label)  # Convert label to a scalar integer
            if label_value not in class_samples:
                class_samples[label_value] = []
            class_samples[label_value].append((audio, label_value))

    # Oversample each class to match the target count
    balanced_samples = []
    for label_value, samples in class_samples.items():
        while len(samples) < target_count:
            samples.append(choice(samples))  # Randomly duplicate
        balanced_samples.extend(samples)

    # Convert back to TensorFlow dataset
    audio_data, labels = zip(*balanced_samples)
    balanced_dataset = tf.data.Dataset.from_tensor_slices((list(audio_data), list(labels)))

    # Shuffle and batch the dataset
    balanced_dataset = balanced_dataset.shuffle(10000).batch(64)
    return balanced_dataset

# %% [markdown]
# Next, we will rebalance the train dataset using oversampling technique.

# %%
# Calculate class distribution before balancing
train_class_counts = get_class_distribution(train_ds)
print("Class distribution before balancing:", train_class_counts)

# Oversample the training dataset
max_class_count = max(train_class_counts.values())
balanced_train_ds = oversample_dataset(train_ds, target_count=max_class_count)

# Calculate class distribution after balancing
balanced_class_counts = get_class_distribution(balanced_train_ds)
print("Class distribution after balancing:", balanced_class_counts)

# Plot the balanced class distribution
plt.figure(figsize=(10, 6))
plt.bar(balanced_class_counts.keys(), balanced_class_counts.values(), color="lightgreen")
plt.xlabel("Class")
plt.ylabel("Number of Samples")
plt.title("Balanced Class Distribution in Training Dataset")
plt.xticks(list(balanced_class_counts.keys()))
plt.grid(axis="y", linestyle="--", alpha=0.7)
plt.show()

# %% [markdown]
# #### Relabling the classes & Reshaping the data

# %% [markdown]
# As mentioned in the task, there are only 12 possible labels for the Test set: yes, no, up, down, left, right, on, off, stop, go, silence, unknown. At this point for simplicity we will consider silent as unknown.
#
# Changing lables to consider only words of interest:

# %%
label_names = np.asarray(['yes', 'no', 'up', 'down', 'left', 'right', 'on', 'off', 'stop', 'go', 'unknown'])
label_names_map = {label: i for i, label in enumerate(label_names)}

# %%
label_names_map
# Out:
# {np.str_('yes'): 0,
#  np.str_('no'): 1,
#  np.str_('up'): 2,
#  np.str_('down'): 3,
#  np.str_('left'): 4,
#  np.str_('right'): 5,
#  np.str_('on'): 6,
#  np.str_('off'): 7,
#  np.str_('stop'): 8,
#  np.str_('go'): 9,
#  np.str_('unknown'): 10}

# %%
# Function to map labels
def map_labels(labels):
    # 10 - unknown label
    return np.array([label_names_map.get(orig_label_names[label], 10) for label in labels], dtype=np.int64)

# Transform labels in train and validation datasets
def preprocess_dataset(dataset):
    def map_and_set_shape(x, y):
        # Apply mapping
        y = tf.numpy_function(map_labels, [y], tf.int64)
        # Explicitly set the shape of the labels to be scalar
        y.set_shape([None])  # [] means a scalar label
        return x, y

    return dataset.map(map_and_set_shape, num_parallel_calls=tf.data.AUTOTUNE)

# %%
train_ds = preprocess_dataset(train_ds)
val_ds = preprocess_dataset(val_ds)

# %% [markdown]
# The dataset now contains batches of audio clips and integer labels. The audio clips have a shape of (batch, samples, channels).

# %%
train_ds.element_spec
# Out:
# (TensorSpec(shape=(None, 16000, None), dtype=tf.float32, name=None),
#  TensorSpec(shape=(None,), dtype=tf.int64, name=None))

# %% [markdown]
# This dataset only contains single channel audio, so the tf.squeeze function is used to drop the extra axis:

# %%
def squeeze(audio, labels):
  audio = tf.squeeze(audio, axis=-1)
  return audio, labels

train_ds = train_ds.map(squeeze, tf.data.AUTOTUNE)
val_ds = val_ds.map(squeeze, tf.data.AUTOTUNE)

submission_ds = submission_ds.map(squeeze, tf.data.AUTOTUNE)

# %%
test_ds = val_ds.shard(num_shards=2, index=0)
val_ds = val_ds.shard(num_shards=2, index=1)

# %% [markdown]
# We will use test_ds to evaluate our model after training and submission_ds to predict the labels of the given test data.

# %% [markdown]
# Inspecting the shape of a single batch from the training dataset:

# %%
for example_audio, example_labels in train_ds.take(1):  
  print(example_audio.shape)
  print(example_labels.shape)
# Out:
# (64, 16000)
# (64,)
# 2025-01-29 17:14:58.403117: I tensorflow/core/framework/local_rendezvous.cc:405] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %% [markdown]
# ### Plotting Audio Waveforms
#
# In this section, we visualize the waveforms of selected audio samples from our training dataset. Waveforms represent the amplitude of the audio signal over time.
#
# We will plot a grid of waveforms for a set of audio samples, each labeled with its corresponding class name.

# %%
label_names[[1,1,3,0]]
# Out:
# array(['no', 'no', 'down', 'yes'], dtype='<U7')

# %%
plt.figure(figsize=(16, 10))
rows = 3
cols = 3
n = rows * cols
for i in range(n):
  plt.subplot(rows, cols, i+1)
  audio_signal = example_audio[i]
  plt.plot(audio_signal)
  plt.title(label_names[example_labels[i]])
  plt.yticks(np.arange(-1.2, 1.2, 0.2))
  plt.ylim([-1.1, 1.1])

# %% [markdown]
# ### Converting waveforms to spectrograms
#
# The waveforms in the dataset are represented in the time domain. We'll transform the waveforms from the time-domain signals into the time-frequency-domain signals by computing the short-time Fourier transform (STFT) to convert the waveforms to as spectrograms, which show frequency changes over time and can be represented as 2D images.

# %%
def get_spectrogram(waveform):
  # Convert the waveform to a spectrogram via a STFT.
  spectrogram = tf.signal.stft(
      waveform, frame_length=255, frame_step=128)
  # Obtain the magnitude of the STFT.
  spectrogram = tf.abs(spectrogram)
  # Add a `channels` dimension, so that the spectrogram can be used
  # as image-like input data with convolution layers (which expect
  # shape (`batch_size`, `height`, `width`, `channels`).
  spectrogram = spectrogram[..., tf.newaxis]
  return spectrogram

# %% [markdown]
# Next, to explore the data we print the shapes of one example's tensorized waveform and the corresponding spectrogram, and play the original audio:

# %%
for i in range(3):
  label = label_names[example_labels[i]]
  waveform = example_audio[i]
  spectrogram = get_spectrogram(waveform)

  print('Label:', label)
  print('Waveform shape:', waveform.shape)
  print('Spectrogram shape:', spectrogram.shape)
  print('Audio playback')
  display.display(display.Audio(waveform, rate=16000))
# Out:
# Label: unknown
# Waveform shape: (16000,)
# Spectrogram shape: (124, 129, 1)
# Audio playback
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Label: stop
# Waveform shape: (16000,)
# Spectrogram shape: (124, 129, 1)
# Audio playback
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Label: unknown
# Waveform shape: (16000,)
# Spectrogram shape: (124, 129, 1)
# Audio playback
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# Now, we define a function for displaying a spectrogram:

# %%
def plot_spectrogram(spectrogram, ax):
  if len(spectrogram.shape) > 2:
    assert len(spectrogram.shape) == 3
    spectrogram = np.squeeze(spectrogram, axis=-1)
  # Convert the frequencies to log scale and transpose, so that the time is
  # represented on the x-axis (columns).
  # Add an epsilon to avoid taking a log of zero.
  log_spec = np.log(spectrogram.T + np.finfo(float).eps)
  height = log_spec.shape[0]
  width = log_spec.shape[1]
  X = np.linspace(0, np.size(spectrogram), num=width, dtype=int)
  Y = range(height)
  ax.pcolormesh(X, Y, log_spec)

# %% [markdown]
# Plot the example's waveform over time and the corresponding spectrogram (frequencies over time):

# %%
fig, axes = plt.subplots(2, figsize=(12, 8))
timescale = np.arange(waveform.shape[0])
axes[0].plot(timescale, waveform.numpy())
axes[0].set_title('Waveform')
axes[0].set_xlim([0, 16000])

plot_spectrogram(spectrogram.numpy(), axes[1])
axes[1].set_title('Spectrogram')
plt.suptitle(label.title())
plt.show()

# %% [markdown]
# Creation of spectrogram datasets from the audio datasets:

# %%
def make_spec_ds(ds):
  return ds.map(
      map_func=lambda audio,label: (get_spectrogram(audio), label),
      num_parallel_calls=tf.data.AUTOTUNE)

# %%
train_spectrogram_ds = make_spec_ds(train_ds)
val_spectrogram_ds = make_spec_ds(val_ds)
submission_spectrogram_ds = make_spec_ds(submission_ds)
test_spectrogram_ds = make_spec_ds(test_ds)

# %% [markdown]
# Examination of the spectrograms for different examples of the dataset:

# %%
for example_spectrograms, example_spect_labels in train_spectrogram_ds.take(1):
  break

# %%
rows = 3
cols = 3
n = rows*cols
fig, axes = plt.subplots(rows, cols, figsize=(16, 9))

for i in range(n):
    r = i // cols
    c = i % cols
    ax = axes[r][c]
    plot_spectrogram(example_spectrograms[i].numpy(), ax)
    ax.set_title(label_names[example_spect_labels[i].numpy()])

plt.show()

# %% [markdown]
# ## Building and training the model

# %% [markdown]
# Adding Dataset.cache and Dataset.prefetch operations to reduce read latency while training the model:

# %%
train_spectrogram_ds = train_spectrogram_ds.cache().shuffle(10000).prefetch(tf.data.AUTOTUNE)
val_spectrogram_ds = val_spectrogram_ds.cache().prefetch(tf.data.AUTOTUNE)
submission_spectrogram_ds = submission_spectrogram_ds.cache().prefetch(tf.data.AUTOTUNE)
test_spectrogram_ds = test_spectrogram_ds.cache().prefetch(tf.data.AUTOTUNE)
print(f"Dataset length: {len(list(train_spectrogram_ds))}")
# Out:
# 2025-01-29 17:15:16.085348: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] ShuffleDatasetV3:38: Filling up shuffle buffer (this may take a while): 783 of 10000
# 2025-01-29 17:15:43.066864: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] ShuffleDatasetV3:38: Filling up shuffle buffer (this may take a while): 786 of 10000
# 2025-01-29 17:15:53.264764: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] ShuffleDatasetV3:38: Filling up shuffle buffer (this may take a while): 787 of 10000
# 2025-01-29 17:17:03.176535: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] ShuffleDatasetV3:38: Filling up shuffle buffer (this may take a while): 790 of 10000
# 2025-01-29 17:17:54.766249: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] ShuffleDatasetV3:38: Filling up shuffle buffer (this may take a while): 791 of 10000
# 2025-01-29 17:17:54.976116: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:480] Shuffle buffer filled.
# Dataset length: 810

# %% [markdown]
# Lets, use a simple convolutional neural network (CNN), since we have transformed the audio files into spectrogram images.
#
# Our model will use the following Keras preprocessing layers:
# * tf.keras.layers.Resizing: to downsample the input to enable the model to train faster.
# * tf.keras.layers.Normalization: to normalize each pixel in the image based on its mean and standard deviation.
#
# For the Normalization layer, its adapt method would first need to be called on the training data in order to compute aggregate statistics (that is, the mean and the standard deviation).

# %%
DROPOUT = 0.25
num_labels = len(label_names)

input_shape = example_spectrograms.shape[1:]
print('Input shape:', input_shape)

# Instantiate the `tf.keras.layers.Normalization` layer.
norm_layer = layers.Normalization()
# Fit the state of the layer to the spectrograms
# with `Normalization.adapt`.
norm_layer.adapt(data=train_spectrogram_ds.map(map_func=lambda spec, label: spec))
def build_simple_model(dropout_rate, activation_function):
  model = tf.keras.Sequential([
      layers.Input(shape=input_shape),
      # Downsample the input.
      layers.Resizing(32, 32),
      # Normalize.
      norm_layer,
      layers.Conv2D(32, 3, activation=activation_function, padding='same'),
      layers.Conv2D(64, 3, activation=activation_function, padding='same'),
      layers.MaxPooling2D(),
      layers.Dropout(dropout_rate),
      layers.Flatten(),
      layers.Dense(128, activation=activation_function),
      layers.Dropout(dropout_rate),
      layers.Dense(num_labels),
  ])
  
  return model

for example_spectrograms, example_spect_labels in train_spectrogram_ds.take(1):
  break
input_shape = example_spectrograms.shape[1:]
print('Input shape:', input_shape)
# Out:
# Input shape: (124, 129, 1)
# Input shape: (124, 129, 1)
# 2025-01-29 17:17:59.641566: I tensorflow/core/framework/local_rendezvous.cc:405] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %%
input_shape = example_spectrograms.shape[1:]

def build_complex_model(dropout_rate, activation_function):
    """
    Builds and returns a deep convolutional neural network (CNN) for audio classification.
    """
    model = tf.keras.Sequential([
        # Input layer
        layers.Input(shape=input_shape),

        # Convolutional block 1
        layers.Conv2D(32, (3, 3), activation=activation_function, padding='same'),
        layers.BatchNormalization(),
        layers.MaxPooling2D((2, 2)),

        # Convolutional block 2
        layers.Conv2D(64, (3, 3), activation=activation_function, padding='same'),
        layers.BatchNormalization(),
        layers.MaxPooling2D((2, 2)),

        # Convolutional block 3
        layers.Conv2D(128, (3, 3), activation=activation_function, padding='same'),
        layers.BatchNormalization(),
        layers.MaxPooling2D((2, 2)),

        # Dropout to prevent overfitting
        layers.Dropout(dropout_rate),

        # Flatten and Dense layers
        layers.Flatten(),
        layers.Dense(256, activation=activation_function),
        layers.Dropout(dropout_rate),
        layers.Dense(len(label_names), activation=activation_function)  # Adjust output size to match the number of classes
    ])
    
    return model

# %% [markdown]
# Define a custom wandb callback class to log the trainin data: Training the model over 7 epochs:

# %%
class CustomWandbCallback(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs=None):
        wandb.log({
            "train_loss": logs.get("loss"),
            "train_accuracy": logs.get("accuracy"),
            "val_loss": logs.get("val_loss"),
            "val_accuracy": logs.get("val_accuracy")
        })

# %% [markdown]
# Define a custom callback class to log the weight changes of each layer after each epoch:

# %%
class LayerWeightTracker(tf.keras.callbacks.Callback):
    def __init__(self):
        super().__init__()
        self.weight_history = {}

    def on_train_begin(self, logs=None):
        """Store initial weights at the beginning of training"""
        for layer in self.model.layers:
            if len(layer.get_weights()) > 0:
                self.weight_history[layer.name] = [[w.copy() for w in layer.get_weights()]]
    def on_epoch_end(self, epoch, logs=None):
        """Store layer weights at the end of each epoch"""
        for layer in self.model.layers:
            if len(layer.get_weights()) > 0:
                self.weight_history[layer.name].append([w.copy() for w in layer.get_weights()])

# Instantiate the callback
weight_tracker = LayerWeightTracker()

# %% [markdown]
# Declare the lists that will store the histories and models of different iterations:

# %%
histories = []
created_models = []

# %% [markdown]
# Train the model for different parameters:

# %% [markdown]
# Or as one function:

# %%
# Define a learning rate schedule
lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=0.001,  # Starting LR
    decay_steps=10000,
    decay_rate=0.9
)

# Use the learning rate schedule in the optimizer
optimizer = tf.keras.optimizers.Adam(learning_rate=lr_schedule)

# %%
def train():
    with wandb.init() as run:
        config = wandb.config
        run.name = f"dp_{config.dropout_rate}_lr_{config.learning_rate}_af_{config.activation_function}_epochs_{config.epochs}"  # Example: "dp_0.50_lr_0.003_epochs_5"
        run.save()  # Ensure the name is saved in the WandB dashboard

        model = build_complex_model(config.dropout_rate, config.activation_function)
        
        # optimizer=tf.keras.optimizers.Adam(learning_rate=config.learning_rate)
        # optimizer=tf.keras.optimizers.SGD(learning_rate=config.learning_rate)
        # optimizer=tf.keras.optimizers.RMSprop(learning_rate=config.learning_rate)

        model.compile(
            optimizer=optimizer,
            loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
            metrics=['accuracy']
        )

        history = model.fit(
            train_spectrogram_ds,
            validation_data=val_spectrogram_ds,
            epochs=config.epochs,
            callbacks=[
                # tf.keras.callbacks.EarlyStopping(verbose=1, patience=2),
                CustomWandbCallback(),  # Add this to log metrics to WandB
                weight_tracker
            ],
        )
        histories.append(history)
        created_models.append(model)


wandb.agent(sweep_id, train)
# Out:
# wandb: Agent Starting Run: 422mkwas with config:
# wandb: 	activation_function: relu
# wandb: 	dropout_rate: 0.3
# wandb: 	epochs: 10
# wandb: 	learning_rate: 0.001
# Tracking run with wandb version 0.19.4
# Run data is saved locally in <code>/home/herman/voice-recognition-project/wandb/run-20250129_172239-422mkwas</code>
# Syncing run <strong><a href='https://wandb.ai/hermanplay-warsaw-university-of-technology/ml_project/runs/422mkwas' target="_blank">hopeful-sweep-1</a></strong> to <a href='https://wandb.ai/hermanplay-warsaw-university-of-technology/ml_project' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/hermanplay-warsaw-university-of-technology/ml_project/sweeps/028l3vuh' target="_blank">https://wandb.ai/hermanplay-warsaw-university-of-technology/ml_project/sweeps/028l3vuh</a>
#  View project at <a href='https://wandb.ai/hermanplay-warsaw-university-of-technology/ml_project' target="_blank">https://wandb.ai/hermanplay-warsaw-university-of-technology/ml_project</a>
#  View sweep at <a href='https://wandb.ai/hermanplay-warsaw-university-of-technology/ml_project/sweeps/028l3vuh' target="_blank">https://wandb.ai/hermanplay-warsaw-university-of-technology/ml_project/sweeps/028l3vuh</a>
#  View run at <a href='https://wandb.ai/hermanplay-warsaw-university-of-technology/ml_project/runs/422mkwas' target="_blank">https://wandb.ai/hermanplay-warsaw-university-of-technology/ml_project/runs/422mkwas</a>
# Epoch 1/10
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1738167762.975417  112272 service.cc:148] XLA service 0x7fa884011d70 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1738167762.975944  112272 service.cc:156]   StreamExecutor device (0): NVIDIA GeForce RTX 2070 SUPER, Compute Capability 7.5
# 2025-01-29 17:22:43.068129: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1738167763.357433  112272 cuda_dnn.cc:529] Loaded cuDNN version 90700
# 2025-01-29 17:22:44.108462: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=2} for conv (f32[64,32,124,129]{3,2,1,0}, u8[0]{0}) custom-call(f32[64,1,124,129]{3,2,1,0}, f32[32,1,3,3]{3,2,1,0}, f32[32]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 2025-01-29 17:22:44.207643: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=2} for conv (f32[64,64,62,64]{3,2,1,0}, u8[0]{0}) custom-call(f32[64,32,62,64]{3,2,1,0}, f32[64,32,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 2025-01-29 17:22:44.502062: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=2} for conv (f32[64,128,31,32]{3,2,1,0}, u8[0]{0}) custom-call(f32[64,64,31,32]{3,2,1,0}, f32[128,64,3,3]{3,2,1,0}, f32[128]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
#   2/810 ━━━━━━━━━━━━━━━━━━━━ 44s 55ms/step - accuracy: 0.2734 - loss: 8.9197
# I0000 00:00:1738167768.246320  112272 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 578/810 ━━━━━━━━━━━━━━━━━━━━ 6s 26ms/step - accuracy: 0.0512 - loss: 2.8267
# 2025-01-29 17:23:03.909720: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=2} for conv (f32[1,128,31,32]{3,2,1,0}, u8[0]{0}) custom-call(f32[1,64,31,32]{3,2,1,0}, f32[128,64,3,3]{3,2,1,0}, f32[128]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 809/810 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.0477 - loss: 2.7233
# 2025-01-29 17:23:12.286000: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=2} for conv (f32[64,32,124,129]{3,2,1,0}, u8[0]{0}) custom-call(f32[64,1,124,129]{3,2,1,0}, f32[32,1,3,3]{3,2,1,0}, f32[32]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kRelu","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 2025-01-29 17:23:12.414828: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=2} for conv (f32[64,64,62,64]{3,2,1,0}, u8[0]{0}) custom-call(f32[64,32,62,64]{3,2,1,0}, f32[64,32,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kRelu","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 2025-01-29 17:23:12.700621: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=2} for conv (f32[64,128,31,32]{3,2,1,0}, u8[0]{0}) custom-call(f32[64,64,31,32]{3,2,1,0}, f32[128,64,3,3]{3,2,1,0}, f32[128]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kRelu","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 810/810 ━━━━━━━━━━━━━━━━━━━━ 34s 33ms/step - accuracy: 0.0477 - loss: 2.7226 - val_accuracy: 0.0345 - val_loss: 2.3979
# Epoch 2/10
# 810/810 ━━━━━━━━━━━━━━━━━━━━ 22s 27ms/step - accuracy: 0.0387 - loss: 2.3988 - val_accuracy: 0.0345 - val_loss: 2.3979
# Epoch 3/10
# 810/810 ━━━━━━━━━━━━━━━━━━━━ 22s 27ms/step - accuracy: 0.0366 - loss: 2.3996 - val_accuracy: 0.0345 - val_loss: 2.3979
# Epoch 4/10
# 810/810 ━━━━━━━━━━━━━━━━━━━━ 23s 28ms/step - accuracy: 0.0369 - loss: 2.3979 - val_accuracy: 0.0345 - val_loss: 2.3979
# Epoch 5/10
# 810/810 ━━━━━━━━━━━━━━━━━━━━ 22s 27ms/step - accuracy: 0.0378 - loss: 2.3980 - val_accuracy: 0.0345 - val_loss: 2.3979
# Epoch 6/10
# 810/810 ━━━━━━━━━━━━━━━━━━━━ 22s 27ms/step - accuracy: 0.0380 - loss: 2.3998 - val_accuracy: 0.0345 - val_loss: 2.3979
# Epoch 7/10
# 810/810 ━━━━━━━━━━━━━━━━━━━━ 22s 28ms/step - accuracy: 0.0354 - loss: 2.3979 - val_accuracy: 0.0345 - val_loss: 2.3979
# Epoch 8/10
# 810/810 ━━━━━━━━━━━━━━━━━━━━ 22s 27ms/step - accuracy: 0.0363 - loss: 2.3979 - val_accuracy: 0.0345 - val_loss: 2.3979
# Epoch 9/10
# 810/810 ━━━━━━━━━━━━━━━━━━━━ 22s 27ms/step - accuracy: 0.0378 - loss: 2.3979 - val_accuracy: 0.0345 - val_loss: 2.3979
# Epoch 10/10
# 810/810 ━━━━━━━━━━━━━━━━━━━━ 22s 27ms/step - accuracy: 0.0363 - loss: 2.3979 - val_accuracy: 0.0345 - val_loss: 2.3979
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>train_accuracy</td><td>█▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train_loss</td><td>█▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_accuracy</td><td>▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>train_accuracy</td><td>0.03681</td></tr><tr><td>train_loss</td><td>2.39792</td></tr><tr><td>val_accuracy</td><td>0.0345</td></tr><tr><td>val_loss</td><td>2.39789</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">dp_0.3_lr_0.001_af_relu_epochs_10</strong> at: <a href='https://wandb.ai/hermanplay-warsaw-university-of-technology/ml_project/runs/422mkwas' target="_blank">https://wandb.ai/hermanplay-warsaw-university-of-technology/ml_project/runs/422mkwas</a><br> View project at: <a href='https://wandb.ai/hermanplay-warsaw-university-of-technology/ml_project' target="_blank">https://wandb.ai/hermanplay-warsaw-university-of-technology/ml_project</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250129_172239-422mkwas/logs</code>
# wandb: Sweep Agent: Waiting for job.
# wandb: Sweep Agent: Exiting.

# %% [markdown]
# Plotting the training and validation loss curves to check how model has improved during training:

# %%
for history in histories:
    metrics = history.history

    plt.figure(figsize=(16,6))
    plt.subplot(1,2,1)
    plt.plot(history.epoch, metrics['loss'], metrics['val_loss'])
    plt.legend(['loss', 'val_loss'])
    plt.ylim([0, max(plt.ylim())])
    plt.xlabel('Epoch')
    plt.ylabel('Loss [CrossEntropy]')

    plt.subplot(1,2,2)
    plt.plot(history.epoch, 100*np.array(metrics['accuracy']), 100*np.array(metrics['val_accuracy']))
    plt.legend(['accuracy', 'val_accuracy'])
    plt.ylim([0, 100])
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy [%]')

# %% [markdown]
# ## Evaluating the model performance

# %%
for model in created_models:
    model.evaluate(test_spectrogram_ds, return_dict=True)
# Out:
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0402 - loss: 2.3979
# 2025-01-29 17:26:45.518874: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=2} for conv (f32[16,32,124,129]{3,2,1,0}, u8[0]{0}) custom-call(f32[16,1,124,129]{3,2,1,0}, f32[32,1,3,3]{3,2,1,0}, f32[32]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kRelu","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 2025-01-29 17:26:45.542108: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=2} for conv (f32[16,64,62,64]{3,2,1,0}, u8[0]{0}) custom-call(f32[16,32,62,64]{3,2,1,0}, f32[64,32,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kRelu","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 2025-01-29 17:26:45.630914: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=2} for conv (f32[16,128,31,32]{3,2,1,0}, u8[0]{0}) custom-call(f32[16,64,31,32]{3,2,1,0}, f32[128,64,3,3]{3,2,1,0}, f32[128]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kRelu","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.0401 - loss: 2.3979

# %% [markdown]
# ### Displaying a confusion matrix and histogram
#
# We'll use a confusion matrix and histogram to check how well the model did classifying each of the words in the test set:

# %%
def display_conf_matrix(model):
    y_pred = model.predict(test_spectrogram_ds)
    y_pred = tf.argmax(y_pred, axis=1)
    y_true = tf.concat(list(test_spectrogram_ds.map(lambda s,lab: lab)), axis=0)
    confusion_mtx = tf.math.confusion_matrix(y_true, y_pred)
    plt.figure(figsize=(10, 8))
    sns.heatmap(confusion_mtx,
                xticklabels=label_names,
                yticklabels=label_names,
                annot=True, fmt='g')
    plt.xlabel('Prediction')
    plt.ylabel('Label')
    plt.show()
    return confusion_mtx

# %%
def display_histogram(model):
    y_pred = model.predict(test_spectrogram_ds)
    y_pred = tf.argmax(y_pred, axis=1)
    label_mapping = {index: value for index, value in enumerate(label_names)}
    label_texts = [label_mapping[label] for label in y_pred.numpy()]
    plt.figure(figsize=(15, 8))
    sns.histplot(label_texts)
    plt.xlabel('Label')
    plt.ylabel('# of predictions')
    plt.show()

# %% [markdown]
# Now, we'll explore confusion matrix and histogram for all labels but unknown:

# %%
def display_conf_matrix_without_unknown(confusion_mtx):
    unknown_index = list(label_names).index("unknown")

    # Remove "unknown" row and column from confusion matrix
    confusion_mtx = np.delete(confusion_mtx, unknown_index, axis=0)  # Remove row
    confusion_mtx = np.delete(confusion_mtx, unknown_index, axis=1)  # Remove column

    # Remove "unknown" from label names
    filtered_labels = np.delete(label_names, unknown_index)

    # Plotting the modified confusion matrix
    plt.figure(figsize=(10, 8))
    sns.heatmap(confusion_mtx,
                xticklabels=filtered_labels,
                yticklabels=filtered_labels,
                annot=True, fmt='g')
    plt.xlabel('Prediction')
    plt.ylabel('Label')
    plt.show()

# %%
def display_histogram_without_unknown(model):
    y_pred = model.predict(test_spectrogram_ds)
    y_pred = tf.argmax(y_pred, axis=1)
    # Create a mapping of indices to labels
    label_mapping = {index: value for index, value in enumerate(label_names)}

    # Filter out predictions with the "unknown" label
    unknown_index = list(label_mapping.values()).index("unknown")
    filtered_y_pred = [label for label in y_pred.numpy() if label != unknown_index]

    # Map the filtered predictions to their text labels
    label_texts = [label_mapping[label] for label in filtered_y_pred]

    # Plot the histogram excluding "unknown" predictions
    plt.figure(figsize=(15, 8))
    sns.histplot(label_texts)
    plt.xlabel('Label')
    plt.ylabel('# of predictions')
    plt.show()

# %%
for model in created_models:
    confusion_matrix = display_conf_matrix(model)
    display_conf_matrix_without_unknown(confusion_matrix)
    display_histogram(model)
    display_histogram_without_unknown(model)
# Out:
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step

# %% [markdown]
# ## Predicting labels with the model

# %% [markdown]
# Next, we will use our model to predict labels for the test sounds. The results, including each sound's filename and its predicted label, will be saved to a CSV file.

# %%
def verify_model_prediction(model):
    y_pred = model.predict(submission_spectrogram_ds)
    y_pred = tf.argmax(y_pred, axis=1)
    print(y_pred)
    label_mapping = {index: value for index, value in enumerate(label_names)}
    label_texts = [label_mapping[label] for label in y_pred.numpy()]
    return label_texts

# %%
def plot_labels(label_texts):
    plt.figure(figsize=(15, 8))
    sns.histplot(label_texts)
    plt.xlabel('Label')
    plt.ylabel('# of predictions')
    plt.show()

# %%
def result_data_frame(label_texts):
    result_df = pd.DataFrame(label_texts, columns=['label'])

    file_names = sorted([path.name for path in test_dir.glob("*/*")])
    result_df["file"] = file_names

    result_df = result_df[['file', 'label']]
    result_df.to_csv('submission.csv', index=False)
    return result_df

# %%
for model in created_models:
    label_texts = verify_model_prediction(model)
    plot_labels(label_texts)
    result_df = result_data_frame(label_texts)
    result_df
# Out:
# 2315/2321 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2025-01-29 17:27:13.680842: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=2} for conv (f32[59,32,124,129]{3,2,1,0}, u8[0]{0}) custom-call(f32[59,1,124,129]{3,2,1,0}, f32[32,1,3,3]{3,2,1,0}, f32[32]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kRelu","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 2025-01-29 17:27:13.881235: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=2} for conv (f32[59,64,62,64]{3,2,1,0}, u8[0]{0}) custom-call(f32[59,32,62,64]{3,2,1,0}, f32[64,32,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kRelu","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 2025-01-29 17:27:14.103462: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=2} for conv (f32[59,128,31,32]{3,2,1,0}, u8[0]{0}) custom-call(f32[59,64,31,32]{3,2,1,0}, f32[128,64,3,3]{3,2,1,0}, f32[128]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kRelu","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 2321/2321 ━━━━━━━━━━━━━━━━━━━━ 24s 10ms/step
# tf.Tensor([0 0 0 ... 0 0 0], shape=(148539,), dtype=int64)

# %% [markdown]
# ## Verification of models prediction

# %% [markdown]
# Let's select a sound and verify its predicted label.

# %%
def verify_model_prediction(model):
    x = test_dir/'audio/clip_00082a7d6.wav' 
    x = tf.io.read_file(str(x))
    x, sample_rate = tf.audio.decode_wav(x, desired_channels=1, desired_samples=16000,)
    x = tf.squeeze(x, axis=-1)
    waveform = x
    x = get_spectrogram(x)
    x = x[tf.newaxis,...]

    prediction = model(x)
    plt.bar(label_names, tf.nn.softmax(prediction[0]))
    plt.show()

    display.display(display.Audio(waveform, rate=16000))

for model in created_models:
    verify_model_prediction(model)
# Out:
# 2025-01-29 17:27:16.686738: W tensorflow/core/framework/op_kernel.cc:1841] OP_REQUIRES failed at whole_file_read_ops.cc:116 : NOT_FOUND: test/audio/clip_00082a7d6.wav; No such file or directory
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# Cell In[70], line 17
#      14     display.display(display.Audio(waveform, rate=16000))
#      16 for model in created_models:
# ---> 17     verify_model_prediction(model)
#
# Cell In[70], line 3, in verify_model_prediction(model)
#       1 def verify_model_prediction(model):
#       2     x = test_dir/'audio/clip_00082a7d6.wav'
# ----> 3     x = tf.io.read_file(str(x))
#       4     x, sample_rate = tf.audio.decode_wav(x, desired_channels=1, desired_samples=16000,)
#       5     x = tf.squeeze(x, axis=-1)
#
# File ~/voice-recognition-project/venv/lib/python3.10/site-packages/tensorflow/python/ops/io_ops.py:134, in read_file(filename, name)
#      97 @tf_export("io.read_file", v1=["io.read_file", "read_file"])
#      98 def read_file(filename, name=None):
#      99   """Reads the contents of file.
#     100
#     101   This operation returns a tensor with the entire contents of the input
#    (...)
#     132     A tensor of dtype "string", with the file contents.
#     133   """
# --> 134   return gen_io_ops.read_file(filename, name)
#
# File ~/voice-recognition-project/venv/lib/python3.10/site-packages/tensorflow/python/ops/gen_io_ops.py:583, in read_file(filename, name)
#     581   pass
#     582 try:
# --> 583   return read_file_eager_fallback(
#     584       filename, name=name, ctx=_ctx)
#     585 except _core._SymbolicException:
#     586   pass  # Add nodes to the TensorFlow graph.
#
# File ~/voice-recognition-project/venv/lib/python3.10/site-packages/tensorflow/python/ops/gen_io_ops.py:606, in read_file_eager_fallback(filename, name, ctx)
#     604 _inputs_flat = [filename]
#     605 _attrs = None
# --> 606 _result = _execute.execute(b"ReadFile", 1, inputs=_inputs_flat,
#     607                            attrs=_attrs, ctx=ctx, name=name)
#     608 if _execute.must_record_gradient():
#     609   _execute.record_gradient(
#     610       "ReadFile", _inputs_flat, _attrs, _result)
#
# File ~/voice-recognition-project/venv/lib/python3.10/site-packages/tensorflow/python/eager/execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# NotFoundError: {{function_node __wrapped__ReadFile_device_/job:localhost/replica:0/task:0/device:CPU:0}} test/audio/clip_00082a7d6.wav; No such file or directory [Op:ReadFile]

# %% [markdown]
# ### Compute and visualize weight change on each individual layer

# %% [markdown]
# Compute the second norm of layer changes.

# %%
layer_changes = {}

for layer_name, weight_list in weight_tracker.weight_history.items():
    changes = []
    for i in range(1, len(weight_list)):  # Iterate over epochs
        norm_diffs = [np.linalg.norm(weight_list[i][j] - weight_list[i-1][j]) for j in range(len(weight_list[i]))]
        changes.append(sum(norm_diffs))  # Sum norms to get total change per epoch
    
    layer_changes[layer_name] = changes

# %% [markdown]
# Plot the changes.

# %%
plt.figure(figsize=(14, 6))

for layer_name, changes in layer_changes.items():
    plt.plot(range(1, len(changes) + 1), changes, label=layer_name, marker="o", linestyle="-", alpha=0.7)

plt.xlabel("Epochs", fontsize=12)
plt.ylabel("Weight Change (L2 Norm)", fontsize=12)
plt.title("Layer Weight Changes During Training", fontsize=14)
plt.legend(loc="upper right", bbox_to_anchor=(1.2, 1), fontsize=10)
plt.grid(True, linestyle="--", alpha=0.5)
plt.show()

# %% [markdown]
# Visualize the changes as a heatmap:

# %%
heatmap_data = np.array([layer_changes[layer] for layer in layer_changes])

plt.figure(figsize=(10, 5))
sns.heatmap(heatmap_data, annot=True, cmap="Reds", xticklabels=range(1, len(changes) + 1), yticklabels=layer_changes.keys())
plt.xlabel("Epochs")
plt.ylabel("Layers")
plt.title("Heatmap of Layer Weight Changes Over Training")
plt.show()

# %% [markdown]
# * The batch normalization layers are the most dynamic during training, adjusting internal statistics to maintain stable feature distributions.
# * Dense layers are actively adjusting weights, refining the decision boundary throughout training.
# * Convolutional layers stabilize early, suggesting they quickly learn essential low-level features and do not require large updates afterward.

# %% [markdown]
# ### Layer Robustness Analysis

# %% [markdown]
# The graph visualizes layer sensitivity to two types of perturbations:
#
# * Re-initialization Robustness – Measures how much performance drops when a layer is reset to its original state.
# * Re-randomization Robustness – Measures how much performance drops when a layer is assigned completely new random weights.
#
# Interpretation of Results:
#
# If performance does not drop much, the layer is not critical for feature extraction.
# If performance drops significantly, that layer learned important features during training.

# %%
retrain_model = False

def reinitialize_layer(model, layer_name):
    for layer in model.layers:
        if layer.name == layer_name and len(layer.get_weights()) > 0:
            original_weights = weight_tracker.weight_history[layer_name][0]  
            
            layer.set_weights(original_weights)


def rerandomise_layer(model, layer_name):
    for layer in model.layers:
        print(f"Layer: {layer.name}, Weights: {layer.get_weights()}")
        if layer.name == layer_name and len(layer.get_weights()) > 0:
            new_weights = []
            for w in layer.get_weights():
                if isinstance(w, np.ndarray):
                    new_weights.append(np.random.randn(*w.shape))
                else:
                    new_weights.append(w)  # Keep non-array parameters unchanged

            layer.set_weights(new_weights)

def test_layer_robustness(model, val_spectrogram_ds):
    layer_names = [layer.name for layer in model.layers if len(layer.get_weights()) > 0]
    reinit_errors = []
    rerand_errors = []

    _, base_acc = model.evaluate(val_spectrogram_ds, verbose=0)

    for layer_name in layer_names:
        # Re-initialize
        temp_model = tf.keras.models.clone_model(model)
        temp_model.build(input_shape=model.input_shape)
        temp_model.set_weights(model.get_weights()) 
        temp_model.compile(optimizer="adam", loss="sparse_categorical_crossentropy", metrics=["accuracy"])
        reinitialize_layer(temp_model, layer_name)
        if retrain_model:
            model.fit(train_spectrogram_ds, validation_data=val_spectrogram_ds, epochs=2)
        _, reinit_acc = temp_model.evaluate(val_spectrogram_ds, verbose=0)
        reinit_errors.append(abs(base_acc - reinit_acc))

        # Re-randomize
        temp_model = tf.keras.models.clone_model(model)
        temp_model.build(input_shape=model.input_shape)
        temp_model.set_weights(model.get_weights())
        temp_model.compile(optimizer="adam", loss="sparse_categorical_crossentropy", metrics=["accuracy"])
        rerandomise_layer(temp_model, layer_name) 
        if retrain_model:
            model.fit(train_spectrogram_ds, validation_data=val_spectrogram_ds, epochs=2)
        _, rerand_acc = temp_model.evaluate(val_spectrogram_ds, verbose=0)
        rerand_errors.append(abs(base_acc - rerand_acc))

    return layer_names, reinit_errors, rerand_errors


for model in created_models:
    layer_names, reinit_errors, rerand_errors = test_layer_robustness(model, val_spectrogram_ds)

    reinit_errors = np.array(reinit_errors)
    rerand_errors = np.array(rerand_errors)

    plt.figure(figsize=(12, 5))

    # Re-initialization Heatmap
    plt.subplot(1, 2, 1)
    sns.heatmap(reinit_errors.reshape(-1, 1), annot=True, cmap="Reds", yticklabels=layer_names)
    plt.xlabel("Re-initialization Robustness")
    plt.title("Layer Sensitivity to Re-initialization")

    # Re-randomization Heatmap
    plt.subplot(1, 2, 2)
    sns.heatmap(rerand_errors.reshape(-1, 1), annot=True, cmap="Reds", yticklabels=layer_names)
    plt.xlabel("Re-randomization Robustness")
    plt.title("Layer Sensitivity to Re-randomization")

    plt.tight_layout()
    plt.show()
# Out:
# Layer: conv2d, Weights: [array([[[[ 0.02793266, -0.00191282,  0.06555913, -0.13124937,
#            0.0940909 ,  0.02713655,  0.03500655, -0.11925504,
#            0.12310409, -0.00832098,  0.02422253,  0.07310846,
#           -0.13820666, -0.14790912, -0.14659768,  0.07390844,
#           -0.02515425, -0.07140692,  0.17352019, -0.07034668,
#           -0.14246964, -0.04404459,  0.14989871, -0.13780984,
#            0.03070454,  0.10140792, -0.06734999,  0.08594282,
#           -0.0747769 ,  0.08309705, -0.14731048, -0.09431627]],
#
#         [[ 0.02670959,  0.11719354,  0.03516268, -0.0669995 ,
#            0.09479409,  0.00150946,  0.12025894, -0.01207483,
#            0.00612891,  0.06094963,  0.04477306, -0.0112375 ,
#           -0.1780011 , -0.06361537,  0.11631697,  0.08168378,
#           -0.04532412, -0.16788973,  0.09974474, -0.14902662,
#        1.7691320e-02, 6.5740416e-08, 3.2668609e-02, 1.4651202e-02,
#        5.3408007e-07, 1.1880407e-07, 3.5160678e-04, 4.1071627e-02,
#        9.0116222e-04, 4.6070845e-08, 2.3839737e-01, 1.7206258e-06,
#        4.5154053e-03, 4.7396810e-05, 5.9911132e-02, 2.9818844e-03,
#        2.1343812e-02, 7.0218141e-03, 7.7365444e-04, 4.9515055e-03,
#        1.0188089e-06, 6.0746074e-02, 7.5752212e-04, 2.5824977e-06],
#       dtype=float32)]
# Layer: max_pooling2d, Weights: []
# Layer: conv2d_1, Weights: [array([[[[-0.08936901, -0.13680123, -0.02866003, ..., -0.05749867,
#            0.02452128, -0.02384878],
#          [-0.03654635, -0.0148222 ,  0.01294986, ...,  0.00997056,
#            0.09589837,  0.03515154],
#          [ 0.10480763,  0.07828164,  0.07243194, ...,  0.02214262,
#            0.016872  , -0.03514446],
#          ...,
#          [ 0.05457045, -0.03642977, -0.02742046, ...,  0.00571363,
#           -0.05490871,  0.01443985],
#          [ 0.10549788,  0.00464955,  0.08752926, ..., -0.00227938,
#            0.01481732,  0.08088271],
#          [-0.03290769,  0.10383472,  0.06379566, ..., -0.0023751 ,
#            0.04062134, -0.02038549]],
#
#         [[ 0.00087124, -0.08889034,  0.1057025 , ..., -0.00704402,
#           -0.00547634,  0.01078248],
#          [ 0.06518752, -0.01868153, -0.03921338, ..., -0.0205774 ,
#           -0.00442495, -0.09704556],
#          [ 0.04827606,  0.08986738,  0.06695941, ...,  0.06823209,
#            0.09359908,  0.01066301],
#          ...,
#          [ 0.06784955,  0.09305487,  0.02295384, ...,  0.01548729,
#           -0.06152365, -0.03095681],
#          [ 0.12085515, -0.04003524, -0.01421145, ..., -0.0813205 ,
#           -0.09490009,  0.06282992],
#          [-0.00828351,  0.03275834, -0.03808733, ...,  0.02916689,
#            0.03600833,  0.07692101]],
#
#         [[ 0.06671473,  0.007051  ,  0.00186217, ..., -0.10844563,
#            0.11492869, -0.00924501],
#          [-0.05295955,  0.04740368, -0.0717152 , ...,  0.07429983,
#           -0.03940049, -0.0287464 ],
#          [-0.03899429,  0.00652005,  0.04111573, ..., -0.06247775,
#            0.0657066 ,  0.03901296],
#          ...,
#          [ 0.08916371,  0.03753211,  0.06008366, ...,  0.03182394,
#            0.02145821, -0.06517866],
#          [-0.010741  , -0.06662728,  0.01454526, ...,  0.01539   ,
#           -0.06114244,  0.02457505],
#          [ 0.06322461,  0.05780969, -0.0239197 , ...,  0.06631988,
#            0.02891677, -0.03452552]]],
#
#
#        [[[-0.01765092, -0.10733645,  0.04432816, ...,  0.08428565,
#            0.12569325,  0.04331189],
#          [ 0.07718552,  0.11239693, -0.00664772, ..., -0.03157303,
#           -0.04171389,  0.07377017],
#          [ 0.03413524,  0.05468598, -0.00348898, ...,  0.0107728 ,
#           -0.01721964,  0.02373051],
#          ...,
#          [ 0.14778662, -0.03281049, -0.05523249, ..., -0.0733624 ,
#            0.04749395,  0.05407779],
#          [-0.00164033,  0.06030041,  0.02764281, ..., -0.00862742,
#           -0.02012128, -0.06284975],
#          [ 0.0162573 ,  0.05605807, -0.06354503, ...,  0.09073402,
#            0.0607842 , -0.01271994]],
#
#         [[-0.08483479, -0.02115688,  0.09585369, ...,  0.07350408,
#            0.0964172 ,  0.05712818],
#          [ 0.02522958,  0.05650022,  0.06929898, ...,  0.07614758,
#           -0.03926148, -0.04604566],
#          [-0.02483713,  0.07567326,  0.01042876, ...,  0.0746885 ,
#           -0.01226054, -0.03901354],
#          ...,
#          [-0.05458334, -0.01189938,  0.01420339, ..., -0.04398346,
#           -0.0434171 ,  0.06028381],
#          [-0.07431101,  0.04289924, -0.01958242, ..., -0.02530583,
#            0.03686352, -0.0623558 ],
#          [-0.014676  ,  0.04607188, -0.00625337, ..., -0.06758562,
#            0.04265971, -0.07148685]],
#
#         [[-0.1058059 , -0.05295359,  0.04965514, ..., -0.10264181,
#            0.00747143, -0.0310417 ],
#          [-0.04512723,  0.02797331,  0.04072062, ..., -0.06161796,
#           -0.06182944, -0.01449258],
#          [ 0.00948061,  0.03730438,  0.07601845, ..., -0.00095362,
#           -0.07297431, -0.02189287],
#          ...,
#          [ 0.05559364,  0.01841469, -0.0586444 , ...,  0.06392254,
#           -0.03612345, -0.01507031],
#          [ 0.04624039, -0.06154339, -0.00674203, ..., -0.04895683,
#           -0.0332358 , -0.05166607],
#          [ 0.06090881,  0.1001492 ,  0.00366446, ..., -0.00332015,
#           -0.08427302,  0.03053759]]],
#
#
#        [[[-0.03057483, -0.06841416, -0.02253046, ..., -0.03002853,
#            0.20352378, -0.07212847],
#          [-0.00226549,  0.05839106, -0.04002495, ..., -0.00949977,
#            0.04709219, -0.07875954],
#          [-0.00847323,  0.07653481,  0.08556499, ...,  0.07308089,
#           -0.06127291,  0.04205677],
#          ...,
#          [-0.01266749, -0.03124392, -0.06546795, ..., -0.01779108,
#            0.03066276,  0.08795694],
#          [ 0.00971772,  0.03741354, -0.04072477, ..., -0.01509997,
#            0.0685325 , -0.07561526],
#          [-0.05616012, -0.02869451, -0.03178161, ..., -0.0037148 ,
#           -0.05479898, -0.07028649]],
#
#         [[ 0.01560161, -0.06872392,  0.08153983, ...,  0.03522744,
#            0.05666852, -0.02565376],
#          [ 0.06212881, -0.06115222,  0.04825256, ...,  0.05404527,
#            0.04926346, -0.08989076],
#          [-0.0137782 ,  0.0601283 ,  0.05122095, ..., -0.07903515,
#           -0.03523007,  0.03154545],
#          ...,
#          [-0.05760301, -0.03440512,  0.05786265, ...,  0.04781652,
#            0.02771278,  0.06615736],
#          [ 0.01185256,  0.05299053,  0.02796691, ..., -0.05004845,
#           -0.03594768,  0.09391716],
#          [ 0.06416582,  0.0660487 ,  0.03728881, ...,  0.02795795,
#           -0.0323692 ,  0.04883454]],
#
#         [[-0.08304007, -0.14014044,  0.06849823, ..., -0.02484689,
#            0.06433968, -0.01275514],
#          [-0.08306541,  0.00272684, -0.03142689, ..., -0.01155305,
#           -0.04170571, -0.04682159],
#          [ 0.02502096,  0.0722884 ,  0.02160763, ...,  0.04514021,
#        -0.00854926, -0.01871685,  0.00782457, -0.00636996,  0.04223863,
#         0.02130835, -0.00553628, -0.00187342,  0.01307034, -0.00739236,
#        -0.00752252, -0.00496446,  0.00078842, -0.00962472, -0.00808631,
#         0.01186683, -0.00499955, -0.0089001 , -0.01109485, -0.01752839,
#         0.00120768,  0.0246442 , -0.01308883, -0.00383642,  0.06434372,
#         0.01593287,  0.00264747, -0.00403239, -0.00456216, -0.02813816,
#         0.02574713,  0.0294943 , -0.01279828, -0.01033784, -0.00751689,
#        -0.01609156,  0.01026271, -0.00613655, -0.0050547 , -0.00547264,
#        -0.00426654,  0.00146818,  0.02900932,  0.00272696, -0.07063492,
#        -0.00712655, -0.01500952, -0.00312734, -0.03445509, -0.00842933,
#        -0.00877486, -0.01926516,  0.02794704, -0.00529718, -0.0164387 ,
#        -0.01033665, -0.02635359, -0.00969272, -0.0131509 , -0.00622422,
#        -0.00672548, -0.00978182, -0.0173647 , -0.00621761, -0.01321619,
#        -0.00461668, -0.00847881, -0.00462915,  0.07588729,  0.00751803,
#        -0.01435899], dtype=float32)]
# Layer: dropout_1, Weights: []
# Layer: dense_1, Weights: [array([[-0.13996871,  0.13436925, -0.02022154, ..., -0.05461628,
#         -0.05379976,  0.00713104],
#        [ 0.10372964,  0.01398683, -0.1247932 , ..., -0.06343938,
#         -0.14135796, -0.08941597],
#        [ 0.02078337, -0.05160454,  0.05670958, ..., -0.0696651 ,
#          0.1097446 , -0.1433003 ],
#        ...,
#        [-0.07010541, -0.09764722, -0.09989017, ..., -0.1247806 ,
#         -0.17029394, -0.05714155],
#        [ 0.00550646, -0.09171882,  0.06716846, ..., -0.00952309,
#          0.09950452, -0.02377579],
#        [-0.03529554, -0.09179249, -0.07598717, ..., -0.12522182,
#          0.00194039, -0.1298624 ]], dtype=float32), array([-0.05991073, -0.0416932 , -0.01908298, -0.03755395, -0.08607484,
#        -0.04200603, -0.01742289, -0.07561585, -0.05180371, -0.04348939,
#        -0.006596  ], dtype=float32)]

# %% [markdown]
# Re-initialization Sensitivity
#
# The dense layer (fully connected layer) is highly sensitive to re-initialization (0.5), indicating that it has learned critical high-level features.
# The dense_1 layer shows minimal sensitivity (0.00031), suggesting it plays a less critical role compared to the primary dense layer.
# Convolutional and batch normalization layers (conv2d, conv2d_1, conv2d_2, batch_normalization, etc.) show zero sensitivity—meaning re-initializing these layers does not significantly impact model performance.

# %% [markdown]
# Re-randomization Sensitivity
#
# Batch normalization layers (batch_normalization, batch_normalization_1, batch_normalization_2) are the most sensitive (0.6). This suggests that batch normalization plays a crucial role in stabilizing learning and normalizing feature distributions.
# The dense layer (0.32) and dense_1 layer (0.26) are also sensitive, meaning changing their weights leads to a noticeable drop in model accuracy.
# Convolutional layers (conv2d, conv2d_1, conv2d_2) remain robust—showing minimal impact when randomized.
#
#
# Batch normalization layers are crucial for maintaining stability. When randomized, they disrupt feature scaling, leading to a significant drop in performance.
# Fully connected layers remain important, but they are less sensitive than batch normalization layers.
# Convolutional layers appear highly robust, meaning feature extraction remains stable even with weight randomization.
